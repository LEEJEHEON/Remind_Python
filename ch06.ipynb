# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(10, 6))
pd.options.display.max_colwidth = 75
pd.options.display.max_columns = 20
np.set_printoptions(precision=4, suppress=True)

# %%
# !cat D:/innotree/python_book/pydata-book/D:/innotree/python_book/pydata-book/examples/ex1.csv
# !cat D:/innotree/python_book/pydata-book/examples/ex1.csv
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
df = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex1.csv")
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !cat D:/innotree/python_book/pydata-book/examples/ex2.csv
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex2.csv", header=None)
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex2.csv", names=["a", "b", "c", "d", "message"])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ["a", "b", "c", "d", "message"]
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex2.csv", names=names, index_col="message")
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !cat D:/innotree/python_book/pydata-book/examples/csv_mindex.csv
parsed = pd.read_csv("D:/innotree/python_book/pydata-book/examples/csv_mindex.csv",
                     index_col=["key1", "key2"])
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
# !cat D:/innotree/python_book/pydata-book/examples/ex3.txt

# %%
result = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex3.txt", sep="\s+")
result
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\admin\AppData\Local\Temp\ipykernel_23632\2236629989.py:1: SyntaxWarning: invalid escape sequence '\s'
#   result = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex3.txt", sep="\s+")
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
# !cat D:/innotree/python_book/pydata-book/examples/ex4.csv
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex4.csv", skiprows=[0, 2, 3])
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !cat D:/innotree/python_book/pydata-book/examples/ex5.csv
result = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv")
result
# pandas는 NA, NULL 처럼 흔히 통용되는 문자를 비어있는 값으로 간주함
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isna(result) # null 값 체크
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv", na_values=["1"])
result # na_values 로 인하여 1을 NAN 으로 만듬
# Out:
#   something    a   b     c   d message
# 0       one  NaN   2   3.0   4     NaN
# 1       two  5.0   6   NaN   8   world
# 2     three  9.0  10  11.0  12     foo

# %%
result.isna()
# Out:
#    something      a      b      c      d  message
# 0      False   True  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result2 = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv", keep_default_na=False)
result2
result2.isna() #  keep_default_na=False 때문에 null 로 변경이 안되었음  
result3 = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv", keep_default_na=False,
                      na_values=["NA"])
result3
result3.isna() #  keep_default_na=False 때문에 null 로 변경이 안되었으나, NA를 NaN 로 변경시킴
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False  False  False    False
# 2      False  False  False  False  False    False

# %%
sentinels = {"message": ["foo", "NA"], "something": ["two"]}
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv", na_values=sentinels,
            keep_default_na=False)
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       NaN  5   6       8   world
# 2     three  9  10  11  12     NaN

# %%
pd.options.display.max_rows = 10

# 큰 파일을 읽기전에 옵션이 제대로 설정이 되어있는지 10개 row만 확인하는 설정

# %%
result = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex6.csv")
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex6.csv", nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
chunker = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex6.csv", chunksize=1000)
type(chunker)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
chunker = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex6.csv", chunksize=1000)

tot = pd.Series([], dtype='int64')
for piece in chunker:
    tot = tot.add(piece["key"].value_counts(), fill_value=0) 
    # key라는 컬럼에서 중복값에 대한 숫자를 모아서 tot 에 추가. 참고로 null은 0으로 변경 

tot = tot.sort_values(ascending=False)

# %%
tot[:10]
# Out:
# key
# E    368.0
# X    364.0
# L    346.0
# O    343.0
# Q    340.0
#      ...
# 5    157.0
# 2    152.0
# 0    151.0
# 9    150.0
# 1    146.0
# Length: 36, dtype: float64

# %%
data = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex5.csv")
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv("D:/innotree/python_book/pydata-book/examples/out.csv")
# !cat D:/innotree/python_book/pydata-book/examples/out.csv
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import sys
data.to_csv(sys.stdout, sep="|")
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout, na_rep="NULL")
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, header=False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, columns=["a", "b", "c"])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %%
# !cat D:/innotree/python_book/pydata-book/examples/ex7.csv

# %%
import csv
f = open("D:/innotree/python_book/pydata-book/examples/ex7.csv")
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
f.close()
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open("D:/innotree/python_book/pydata-book/examples/ex7.csv") as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
obj = """
{"name": "Wes",
 "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
              {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'cities_lived': ['Akron', 'Nashville', 'New York', 'San Francisco'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 34, 'hobbies': ['guitars', 'soccer']},
#   {'name': 'Katie', 'age': 42, 'hobbies': ['diving', 'art']}]}

# %%
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"], "pet": null, "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]}, {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]}'

# %%
siblings = pd.DataFrame(result["siblings"], columns=["name", "age","hobbies"])
siblings
# json을 df로 변환
# Out:
#     name  age            hobbies
# 0  Scott   34  [guitars, soccer]
# 1  Katie   42      [diving, art]

# %%
# !cat D:/innotree/python_book/pydata-book/examples/example.json

# %%
data = pd.read_json("D:/innotree/python_book/pydata-book/examples/example.json")
data
# 별다른 옵션이 없다면 json 키값을 열 이름으로 침
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data.to_json(sys.stdout)
data.to_json(sys.stdout, orient="records")
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
tables = pd.read_html("D:/innotree/python_book/pydata-book/examples/fdic_failed_bank_list.html")
len(tables)
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures["Closing Date"])
close_timestamps.dt.year.value_counts()
# Out:
# Closing Date
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
#        ...
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: count, Length: 15, dtype: int64

# %%
from lxml import objectify

path = "D:/innotree/python_book/pydata-book/datasets/mta_perf/Performance_MNR.xml"
with open(path) as f:
    parsed = objectify.parse(f)
root = parsed.getroot()

# %%
data = []

skip_fields = ["PARENT_SEQ", "INDICATOR_SEQ",
               "DESIRED_CHANGE", "DECIMAL_PLACES"]

# <INDICATOR> 요소의 값을 뽑아옴 
for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields: # 해당 태그들은 제외 
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                                                   DESCRIPTION  \
# 0  Percent of commuter trains that arrive at their destinations within 5 m...
# 1  Percent of commuter trains that arrive at their destinations within 5 m...
# 2  Percent of commuter trains that arrive at their destinations within 5 m...
# 3  Percent of commuter trains that arrive at their destinations within 5 m...
# 4  Percent of commuter trains that arrive at their destinations within 5 m...
#
#    PERIOD_YEAR  PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT  \
# ...

# %%
perf2 = pd.read_xml(path)
perf2.head()
# Out:
#    INDICATOR_SEQ  PARENT_SEQ           AGENCY_NAME  \
# 0          28445         NaN  Metro-North Railroad
# 1          28445         NaN  Metro-North Railroad
# 2          28445         NaN  Metro-North Railroad
# 3          28445         NaN  Metro-North Railroad
# 4          28445         NaN  Metro-North Railroad
#
#                          INDICATOR_NAME  \
# 0  On-Time Performance (West of Hudson)
# 1  On-Time Performance (West of Hudson)
# 2  On-Time Performance (West of Hudson)
# 3  On-Time Performance (West of Hudson)
# 4  On-Time Performance (West of Hudson)
#
#                                                                   DESCRIPTION  \
# 0  Percent of commuter trains that arrive at their destinations within 5 m...
# 1  Percent of commuter trains that arrive at their destinations within 5 m...
# 2  Percent of commuter trains that arrive at their destinations within 5 m...
# 3  Percent of commuter trains that arrive at their destinations within 5 m...
# ...

# %%
frame = pd.read_csv("D:/innotree/python_book/pydata-book/examples/ex1.csv")
frame
frame.to_pickle("D:/innotree/python_book/pydata-book/examples/frame_pickle")

# %%
pd.read_pickle("D:/innotree/python_book/pydata-book/examples/frame_pickle")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !rm D:/innotree/python_book/pydata-book/examples/frame_pickle
# Out:
# 'rm'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
fec = pd.read_parquet('D:/innotree/python_book/pydata-book/datasets/fec/fec.parquet')

# %%
xlsx = pd.ExcelFile("D:/innotree/python_book/pydata-book/examples/ex1.xlsx")
# csv 인데 xlsx 로도 읽을 수 있음

# %%
xlsx.sheet_names
# Out:
# ['Sheet1']

# %%
xlsx.parse(sheet_name="Sheet1")
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
xlsx.parse(sheet_name="Sheet1", index_col=0)
# index_col을 통해 인덱스 열 지정
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame = pd.read_excel("D:/innotree/python_book/pydata-book/examples/ex1.xlsx", sheet_name="Sheet1")
frame
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
writer = pd.ExcelWriter("D:/innotree/python_book/pydata-book/examples/ex2.xlsx")
frame.to_excel(writer, "Sheet1")
writer.close()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_23632\3405811245.py:2: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   frame.to_excel(writer, "Sheet1")

# %%
frame.to_excel("D:/innotree/python_book/pydata-book/examples/ex2.xlsx")

# %%
# !rm D:/innotree/python_book/pydata-book/examples/ex2.xlsx

# %%
# !rm -f D:/innotree/python_book/pydata-book/examples/mydata.h5

# %%
frame = pd.DataFrame({"a": np.random.standard_normal(100)})
store = pd.HDFStore("D:/innotree/python_book/pydata-book/examples/mydata.h5")
store["obj1"] = frame
store["obj1_col"] = frame["a"]
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: D:/innotree/python_book/pydata-book/examples/mydata.h5

# %%
store["obj1"]
# Out:
#            a
# 0  -0.204708
# 1   0.478943
# 2  -0.519439
# 3  -0.555730
# 4   1.965781
# ..       ...
# 95  0.795253
# 96  0.118110
# 97 -0.748532
# 98  0.584970
# 99  0.152677
#
# [100 rows x 1 columns]

# %%
store.put("obj2", frame, format="table")
store.select("obj2", where=["index >= 10 and index <= 15"])
store.close()

# %%
frame.to_hdf("D:/innotree/python_book/pydata-book/examples/mydata.h5", "obj3", format="table")
pd.read_hdf("D:/innotree/python_book/pydata-book/examples/mydata.h5", "obj3", where=["index < 5"])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_23632\1576645276.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_hdf except for the argument 'path_or_buf' will be keyword-only.
#   frame.to_hdf("D:/innotree/python_book/pydata-book/examples/mydata.h5", "obj3", format="table")
#           a
# 0 -0.204708
# 1  0.478943
# 2 -0.519439
# 3 -0.555730
# 4  1.965781

# %%
import os
os.remove("D:/innotree/python_book/pydata-book/examples/mydata.h5")

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url)
resp.raise_for_status()
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]["title"]
# Out:
# 'Restrict clipping of DataFrame.corr only when cov=False'

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61214',
#   'id': 2965010194,
#   'node_id': 'PR_kwDOAA0YD86RBGzn',
#   'number': 61214,
#   'title': 'Restrict clipping of DataFrame.corr only when cov=False',
#   'user': {'login': 'j-hendricks',
#    'id': 105813545,
#    'node_id': 'U_kgDOBk6WKQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105813545?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/j-hendricks',
#    'html_url': 'https://github.com/j-hendricks',
# ...

# %%
issues = pd.DataFrame(data, columns=["number", "title",
                                     "labels", "state"])
issues
# Out:
#     number  \
# 0    61214
# 1    61212
# 2    61211
# 3    61210
# 4    61209
# ..     ...
# 25   61168
# 26   61166
# 27   61164
# 28   61162
# 29   61161
#
#                                                                          title  \
# 0                      Restrict clipping of DataFrame.corr only when cov=False
# 1     BUG: OverflowError when fillna on DataFrame with a pd.Timestamp (#61208)
# 2          BUG: Preserve extension dtypes in MultiIndex during concat (#58421)
# 3               ENH: Add ignore_empty and ignore_all_na arguments to pd.concat
# 4                   ENH: Consistent NA handling in `unique()`, and `nunique()`
# ..                                                                         ...
# 25                                        ENH: Accept no fields for groupby by
# 26                              ENH: Enable nsmallest/nlargest on object dtype
# 27                                           ENH: merge_asof threshold minimum
# ...

# %%
import sqlite3

query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""

con = sqlite3.connect("mydata.sqlite")
con.execute(query)
con.commit()

# %%
data = [("Atlanta", "Georgia", 1.25, 6),
        ("Tallahassee", "Florida", 2.6, 3),
        ("Sacramento", "California", 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute("SELECT * FROM test")
rows = cursor.fetchall() 
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description # 열 이름만 제공 
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine("sqlite:///mydata.sqlite")
pd.read_sql("SELECT * FROM test", db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
# !rm mydata.sqlite
