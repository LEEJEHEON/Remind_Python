# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
pd.options.display.max_colwidth = 80
pd.options.display.max_columns = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc("figure", figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline
plt.ion()

# %%
import matplotlib
print("Backend:", matplotlib.get_backend())
print("Version:", matplotlib.__version__)
# Out:
# Backend: inline
# Version: 3.10.0

# %%
# 1. 먼저 필요한 라이브러리들을 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 2. 그래프 설정
plt.style.use('default')  # 기본 스타일 사용
plt.rcParams['figure.figsize'] = [10, 6]  # 그래프 크기 설정

# 3. 데이터 생성 및 그래프 그리기
data = np.arange(10)
plt.figure()  # 새로운 figure 생성
plt.plot(data)
plt.show()  # 명시적으로 그래프 표시

# %%
data = np.arange(10)
data
plt.plot(data)

# plt.show()

# %%
fig = plt.figure()

# %%
# 1개의 그림의 여러 subplot 을 추가할때 add_subplot을 함 
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
ax3.plot(np.random.standard_normal(50).cumsum(), color="black",
         linestyle="dashed")

display(fig) 
# plt.show(fig)

# %%
ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3);
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30));

# %%
display(fig)

# %%
plt.close("all")

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.standard_normal(500), bins=50,
                        color="black", alpha=0.5)
fig.subplots_adjust(wspace=0, hspace=0)
# 가로 세로 간격을 0으로 함. 그랬더니 축이 서로 겹침

# %%
display(fig)

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot()
ax.plot(np.random.standard_normal(30).cumsum(), color="skyblue",
        linestyle="dashed", marker="o");

# %%
display(fig)

# %%
plt.close("all")

# %%
fig = plt.figure()
ax = fig.add_subplot()
data = np.random.standard_normal(30).cumsum()
ax.plot(data, color="black", linestyle="dashed", label="Default");
ax.plot(data, color="black", 
        drawstyle="steps-post", label="steps-post");
ax.legend()

# %%
display(fig)

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum());

# %%
display(fig)

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(["one", "two", "three", "four", "five"],
                            rotation=30, fontsize=8)

# %%
ax.set_xlabel("Stages")
ax.set_title("My first matplotlib plot")
# Out:
# Text(0.5, 1.0, 'My first matplotlib plot')

# %%
display(fig)

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color="black", label="one");
ax.plot(np.random.randn(1000).cumsum(), color="blue", linestyle="dashed",
        label="two");
ax.plot(np.random.randn(1000).cumsum(), color="red", linestyle="dotted",
        label="three");

# %%
ax.legend()

# %%
display(fig)

# %%
from datetime import datetime

fig, ax = plt.subplots()

data = pd.read_csv("D:/innotree/python_book/pydata-book/examples/spx.csv", index_col=0, parse_dates=True)
spx = data["SPX"]

spx.plot(ax=ax, color="black")

crisis_data = [
    (datetime(2007, 10, 11), "Peak of bull market"),
    (datetime(2008, 3, 12), "Bear Stearns Fails"),
    (datetime(2008, 9, 15), "Lehman Bankruptcy")
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor="black", headwidth=4, width=2,
                                headlength=4),
                horizontalalignment="left", verticalalignment="top")
# annotate 로 지정한 위치에 레이블 추가 

# Zoom in on 2007-2010
ax.set_xlim(["1/1/2007", "1/1/2011"])
ax.set_ylim([600, 1800])

ax.set_title("Important dates in the 2008–2009 financial crisis")
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008–2009 financial crisis')

# %%
display(fig)

# %%
ax.set_title("Important dates in the 2008–2009 financial crisis")

# %%
fig, ax = plt.subplots(figsize=(12, 6))
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color="black", alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color="blue", alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color="green", alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
display(fig)

# %%
plt.close("all")

# %%
s = pd.Series(np.random.standard_normal(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.standard_normal((10, 4)).cumsum(0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
plt.style.use('grayscale')
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#            A         B         C         D
# 0   0.396062  0.037402 -0.108530  0.533811
# 10 -0.166027  0.365297  0.798685  0.139973
# 20 -0.704436  1.164152 -0.553763  2.354324
# 30 -0.909643  0.598571 -0.605868  1.470214
# 40 -0.870100  0.160411 -1.576454  1.221147
# 50  0.120927  0.037619 -1.560433  1.192753
# 60 -1.542705  0.270502 -1.349182  2.262333
# 70 -1.332871  0.470443  0.480534  4.667918
# 80 -0.663091 -1.026560  0.928851  6.708976
# 90  0.164254 -1.572684  1.457125  8.620208

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.uniform(size=16), index=list("abcdefghijklmnop"))
data.plot.bar(ax=axes[0], color="black", alpha=0.7)
data.plot.barh(ax=axes[1], color="black", alpha=0.7)
# Out:
# <Axes: >

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.uniform(size=(6, 4)),
                  index=["one", "two", "three", "four", "five", "six"],
                  columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df
df.plot.bar()
# Out:
# <Axes: >

# %%
plt.figure()

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <Axes: >

# %%
display(plt.show())
# Out:
# None

# %%
plt.close("all")

# %%
tips = pd.read_csv("D:/innotree/python_book/pydata-book/examples/tips.csv")
tips.head()
party_counts = pd.crosstab(tips["day"], tips["size"])
party_counts = party_counts.reindex(index=["Thur", "Fri", "Sat", "Sun"])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
# Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(axis="columns"),
                              axis="index")
party_pcts
party_pcts.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='day'>

# %%
plt.show()

# %%
plt.close("all")

# %%
import seaborn as sns

tips["tip_pct"] = tips["tip"] / (tips["total_bill"] - tips["tip"])
tips.head()
sns.barplot(x="tip_pct", y="day", data=tips, orient="h")
# Out:
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
plt.show()
# 선은 95% 신뢰구간

# %%
plt.close("all")

# %%
sns.barplot(x="tip_pct", y="day", hue="time", data=tips, orient="h")
# Out:
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
plt.show()
# hue 옵션을 통해 분류

# %%
plt.close("all")

# %%
sns.set_style("whitegrid")

# %%
plt.figure()

# %%
tips["tip_pct"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.show()

# %%
plt.figure()

# %%
tips["tip_pct"].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
plt.show()

# %%
plt.figure()

# %%
comp1 = np.random.standard_normal(200)
comp2 = 10 + 2 * np.random.standard_normal(200)
values = pd.Series(np.concatenate([comp1, comp2]))

sns.histplot(values, bins=100, color="black")
# Out:
# <Axes: ylabel='Count'>

# %%
plt.show()

# %%
macro = pd.read_csv("D:/innotree/python_book/pydata-book/examples/macrodata.csv")
data = macro[["cpi", "m1", "tbilrate", "unemp"]]
trans_data = np.log(data).diff().dropna()
trans_data.tail()
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.figure()

# %%
ax = sns.regplot(x="m1", y="unemp", data=trans_data)
ax.set_title("Changes in log(m1) versus log(unemp)")
# regplot 로 산포도랑 선형 회귀선을 같이 그림
# Out:
# Text(0.5, 1.0, 'Changes in log(m1) versus log(unemp)')

# %%
plt.show()

# %%
sns.pairplot(trans_data, diag_kind="kde", plot_kws={"alpha": 0.2})

# %%
plt.show()

# %%
sns.catplot(x="day", y="tip_pct", hue="time", col="smoker",
            kind="bar", data=tips[tips.tip_pct < 1])

# %%
plt.show()

# %%
sns.catplot(x="day", y="tip_pct", row="time",
            col="smoker",
            kind="bar", data=tips[tips.tip_pct < 1])

# %%
plt.show()

# %%
sns.catplot(x="tip_pct", y="day", kind="box",
            data=tips[tips.tip_pct < 0.5])

# %%
plt.show()
